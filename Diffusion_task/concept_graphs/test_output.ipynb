# %%
import numpy as np
import matplotlib.pyplot as plt

file_path = '/data2/jiawei/llm-understanding/Diffusion_task/concept_graphs/output/single-body_2d_3classes/H32-train1/5000_0.4_256_500_200_0.0001_None_1500_2.0_1_more_triangle_equal2/image_111_ep99.npz'

# %%
# Load the .npz file
data = np.load(file_path)

# List all arrays in the file
keys = data.files
print("Keys in NPZ file:", keys)

# Plot a few images from each array
for key in keys:
    images = data[key] 
    print(f"Shape of {key}:", images.shape)

    # Loop through the first batch and first few images
    for i in range(5):  # Display 5 images
        # img = images[0, i]  # First batch, ith image (Shape: 3, 28, 28)
        img = images[i] # ith image (Shape: 3, 28, 28)
        print(img.max())
        print(img.min())

        # Transpose to (28, 28, 3) for imshow
        img = np.transpose(img, (1, 2, 0))
        # img = (img +1) /2
        img = img.clip(0, 1)
        
        plt.figure()
        plt.title(f"{key} - Image {i+1}")
        plt.imshow(img)
        plt.axis('off')

plt.show()

# Close the file
data.close()
# Out:
# Keys in NPZ file: ['x_gen']
# Shape of x_gen: (64, 3, 28, 28)
# 1.0687253
# 0.023229072
# 1.078732
# 0.04734277
# 1.0724736
# 0.033202726
# 1.0874121
# 0.01870061
# 1.0910646
# 0.019046837

# %%
from PIL import Image

# Path to your PNG image
image_path = '/data2/jiawei/llm-understanding/concept_graphs/input/single-body_2d_3classes/train/CLEVR_000_15000.png'

# Load the image
img = Image.open(image_path)

# Display image size
print(f"Image size: {img.size}")  # Output: (width, height)


# Check image mode (e.g., RGB, RGBA, etc.)
print(f"Image mode: {img.mode}")
# Out:
# Image size: (28, 28)
# Image mode: RGB

# %%
import json
import itertools
dataset = "single-body_2d_3classes"
properties_json = "properties_"+dataset+".json"
with open(properties_json, 'r') as f: 
    properties = json.load(f)

keys, values = zip(*properties.items())
permutations = [dict(zip(keys, v)) for v in itertools.product(*values)]
    
configs = []
for permutation in permutations:
    configs.append("".join(permutation.values()))

# %%
configs
# Out:
# ['000', '001', '010', '011', '100', '101', '110', '111']
